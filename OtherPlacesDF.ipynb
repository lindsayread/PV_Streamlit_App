# %%
import requests
import json
import time

import pandas as pd
from googletrans import Translator, constants
from pprint import pprint

# %%
class GooglePlaces(object):
    def __init__(self, apiKey):
        super(GooglePlaces, self).__init__()
        self.apiKey = apiKey
        
    def search_places_by_coordinate(self, location, radius, types):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        places = []
        params = {
            'location': location,
            'radius': radius,
            'types': types,
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        results =  json.loads(res.content)
        places.extend(results['results'])
        time.sleep(2)
        while "next_page_token" in results:
            params['pagetoken'] = results['next_page_token'],
            res = requests.get(endpoint_url, params = params)
            results = json.loads(res.content)
            places.extend(results['results'])
            time.sleep(2)
        return places
    
    def get_place_details(self, place_id, fields):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/details/json"
        params = {
            'placeid': place_id,
            'fields': ",".join(fields),
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        place_details =  json.loads(res.content)
        return place_details

# %%
api = GooglePlaces("AIzaSyAVGW0SZpsJgHMsdW2jYOOfm-iEzY2oKIY")

# %%
coordinates = ["20.691042 -105.275793",
              "20.623661 -105.221570",
              "20.632749 -105.221477",
              "20.641054 -105.221291",
              "20.650576 -105.219386",
              "20.655880 -105.227471",
              "20.674095 -105.248472",
              "20.668400 -105.249680",
              "20.664922 -105.257299",
              "20.661314 -105.249726",
              "20.661401 -105.233046",
              "20.653401 -105.238575",
              "20.645880 -105.23656",
              "20.638749 -105.230676",
              "20.631444 -105.228353",
              "20.624443 -105.227052",
              "20.614224 -105.228957",
              "20.607962 -105.234626",
              "20.602379 -105.235771"]

# %%
restaurants1 = api.search_places_by_coordinate("20.691042 -105.275793", "1000", "restaurant")
restaurants1[0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 20.6911818, 'lng': -105.2804769},
#   'viewport': {'northeast': {'lat': 20.6925106802915,
#     'lng': -105.2791783197085},
#    'southwest': {'lat': 20.6898127197085, 'lng': -105.2818762802915}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#  'name': "Claudio's Place",
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 2448,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104016353040611345370">Rolando Elías S.</a>'],
#    'photo_reference': 'CkQ0AAAApyTKrCRX4OJcAmqo-vtoY9TPmHnGCRXQ7s0i2dMe40nWQ-qeF4pTmcYYYefW8UCaSWy64vkvr8ZVa-e_L0KOFxIQ41zX-OAIJxTER2wGAm0EARoUI33Ch_CipmgS_P68di4opreLQw4',
#    'width': 3264}],
#  'place_id': 'ChIJMUwQD51GIYQRJgins7Zd2Vg',
#  'plus_code': {'compound_code': 'MPR9+FR Jarretaderas, Nayarit, Mexico',
#   'global_code': '75GPMPR9+FR'},
#  'rating': 4.4,
#  'reference': 'ChIJMUwQD51GIYQRJgins7Zd2Vg',
# ...

# %%
restaurants1df = pd.DataFrame(restaurants1)
restaurants1df.shape
# Out:
# (44, 15)

# %%
restaurants1df.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6917245, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6919927, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6898023, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6931104, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                            name        opening_hours  \
# 0                               Claudio's Place   {'open_now': True}
# 1                                        Quesos                  NaN
# ...

# %%
restaurants1df.iloc[0].types
# Out:
# ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment']

# %%
rest2 = api.search_places_by_coordinate("20.623661 -105.221570", "500", "restaurant")
rest3 = api.search_places_by_coordinate("20.632749 -105.221477", "500", "restaurant")
rest4 = api.search_places_by_coordinate("20.641054 -105.221291", "500", "restaurant")
rest5 = api.search_places_by_coordinate("20.650576 -105.219386", "500", "restaurant")
rest6 = api.search_places_by_coordinate("20.655880 -105.227471", "500", "restaurant")
rest7 = api.search_places_by_coordinate("20.674095 -105.248472", "500", "restaurant")
rest8 = api.search_places_by_coordinate("20.668400 -105.249680", "500", "restaurant")
rest9 = api.search_places_by_coordinate("20.664922 -105.257299", "500", "restaurant")
rest10 = api.search_places_by_coordinate("20.661314 -105.249726", "500", "restaurant")
rest11 = api.search_places_by_coordinate("20.661401 -105.233046", "500", "restaurant")
rest12 = api.search_places_by_coordinate("20.653401 -105.238575", "500", "restaurant")
rest13 = api.search_places_by_coordinate("20.645880 -105.23656", "500", "restaurant")
rest14 = api.search_places_by_coordinate("20.638749 -105.230676", "500", "restaurant")
rest15 = api.search_places_by_coordinate("20.631444 -105.228353", "500", "restaurant")
rest16 = api.search_places_by_coordinate("20.624443 -105.227052", "500", "restaurant")
rest17 = api.search_places_by_coordinate("20.614224 -105.228957", "500", "restaurant")
rest18 = api.search_places_by_coordinate("20.607962 -105.234626", "500", "restaurant")
rest19 = api.search_places_by_coordinate("20.602379 -105.235771", "500", "restaurant")

rest20 = api.search_places_by_coordinate("20.604789 -105.228561", "700", "restaurant")
rest21 = api.search_places_by_coordinate("20.591934 -105.241779", "1000", "restaurant")
rest22 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "restaurant")
rest23 = api.search_places_by_coordinate("20.682131 -105.283878", "1000", "restaurant")

# %%
rest2df = pd.DataFrame(rest2)
rest3df = pd.DataFrame(rest3)
rest4df = pd.DataFrame(rest4)
rest5df = pd.DataFrame(rest5)
rest6df = pd.DataFrame(rest6)
rest7df = pd.DataFrame(rest7)
rest8df = pd.DataFrame(rest8)
rest9df = pd.DataFrame(rest9)
rest10df = pd.DataFrame(rest10)
rest11df = pd.DataFrame(rest11)
rest12df = pd.DataFrame(rest12)
rest13df = pd.DataFrame(rest13)
rest14df = pd.DataFrame(rest14)
rest15df = pd.DataFrame(rest15)
rest16df = pd.DataFrame(rest16)
rest17df = pd.DataFrame(rest17)
rest18df = pd.DataFrame(rest18)
rest19df = pd.DataFrame(rest19)
rest20df = pd.DataFrame(rest20)
rest21df = pd.DataFrame(rest21)
rest22df = pd.DataFrame(rest22)
rest23df = pd.DataFrame(rest23)

# %%
print(
    restaurants1df.shape,
    rest2df.shape,
    rest3df.shape,
    rest4df.shape,
    rest5df.shape,
    rest6df.shape,
    rest7df.shape,
    rest8df.shape,
    rest9df.shape,
    rest10df.shape,
    rest11df.shape,
    rest12df.shape,
    rest13df.shape,
    rest14df.shape,
    rest15df.shape,
    rest16df.shape,
    rest17df.shape,
    rest18df.shape,
    rest19df.shape,
    rest20df.shape,
    rest21df.shape,
    rest22df.shape,
    rest23df.shape)
# Out:
# (44, 15) (56, 15) (60, 15) (46, 15) (60, 16) (55, 16) (42, 15) (60, 16) (17, 15) (38, 16) (31, 15) (60, 15) (33, 16) (60, 15) (60, 15) (60, 15) (60, 16) (60, 15) (60, 15) (60, 15) (35, 15) (16, 15) (35, 15)

# %%
pv1df.columns
# Out:
# Index(['business_status', 'geometry', 'icon', 'name', 'opening_hours',
#        'photos', 'place_id', 'plus_code', 'rating', 'reference', 'scope',
#        'types', 'user_ratings_total', 'vicinity'],
#       dtype='object')

# %%
restaurants_basic = pd.concat([restaurants1df,rest2df,rest3df,rest4df,rest5df,rest6df,rest7df,rest8df,rest9df,rest10df,rest11df,rest12df,
                       rest13df,rest14df,rest15df,rest16df,rest17df,rest18df,rest19df,rest20df,rest21df,rest22df,rest23df,], 
                       ignore_index=True, sort=False)

# %%
restaurants_basic = restaurants_basic.drop_duplicates(subset=['place_id'], inplace=False)

# %%
restaurants_basic.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6938154, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6917245, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6919927, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6898023, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                            name       opening_hours  \
# 0                               Claudio's Place  {'open_now': True}
# 1                The Blue Shrimp Nuevo Vallarta  {'open_now': True}
# ...

# %%
restaurants_basic['place_type'] = "restaurant"
restaurants_basic.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6938154, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6917245, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6919927, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6898023, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                            name       opening_hours  \
# 0                               Claudio's Place  {'open_now': True}
# 1                The Blue Shrimp Nuevo Vallarta  {'open_now': True}
# ...

# %% [markdown]
# ## Bars

# %%
bar1 = api.search_places_by_coordinate("20.691042 -105.275793", "1000", "bar")
bar1[0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 20.6911818, 'lng': -105.2804769},
#   'viewport': {'northeast': {'lat': 20.6925106802915,
#     'lng': -105.2791783197085},
#    'southwest': {'lat': 20.6898127197085, 'lng': -105.2818762802915}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#  'name': "Claudio's Place",
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 2448,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104016353040611345370">Rolando Elías S.</a>'],
#    'photo_reference': 'CkQ0AAAAc365z4zQkYRxVKLF0-vFRe3Y7_EIZFnklCIEyx9wBjpPRvXbFA3kFcKpnC6PqisALQh4yhOGh8Ilp6j8z581lhIQAIzG8OK9zcql-xhlf4R6iRoUSlXuE_qmHgu4ioppOLmfzEj6v3g',
#    'width': 3264}],
#  'place_id': 'ChIJMUwQD51GIYQRJgins7Zd2Vg',
#  'plus_code': {'compound_code': 'MPR9+FR Jarretaderas, Nayarit, Mexico',
#   'global_code': '75GPMPR9+FR'},
#  'rating': 4.4,
#  'reference': 'ChIJMUwQD51GIYQRJgins7Zd2Vg',
# ...

# %%
bar1df = pd.DataFrame(bar1)
bar1df.shape
# Out:
# (4, 15)

# %%
bar1df.head()
# Out:
#       business_status                                           geometry  \
# 0         OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 1  CLOSED_TEMPORARILY  {'location': {'lat': 20.6944041, 'lng': -105.2...
# 2         OPERATIONAL  {'location': {'lat': 20.6913596, 'lng': -105.2...
# 3  CLOSED_TEMPORARILY  {'location': {'lat': 20.6995215, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                             name       opening_hours  \
# 0                Claudio's Place  {'open_now': True}
# 1  Salon de Eventos Jarretaderas                 NaN
# 2             Arriba Tequila Bar  {'open_now': True}
# 3                 Cuatro Vientos                 NaN
#
#                                               photos  \
# ...

# %%
bar2 = api.search_places_by_coordinate("20.623661 -105.221570", "500", "bar")
bar3 = api.search_places_by_coordinate("20.632749 -105.221477", "500", "bar")
bar4 = api.search_places_by_coordinate("20.641054 -105.221291", "500", "bar")
bar5 = api.search_places_by_coordinate("20.650576 -105.219386", "500", "bar")
bar6 = api.search_places_by_coordinate("20.655880 -105.227471", "500", "bar")
bar7 = api.search_places_by_coordinate("20.674095 -105.248472", "500", "bar")
bar8 = api.search_places_by_coordinate("20.668400 -105.249680", "500", "bar")
bar9 = api.search_places_by_coordinate("20.664922 -105.257299", "500", "bar")
bar10 = api.search_places_by_coordinate("20.661314 -105.249726", "500", "bar")
bar11 = api.search_places_by_coordinate("20.661401 -105.233046", "500", "bar")
bar12 = api.search_places_by_coordinate("20.653401 -105.238575", "500", "bar")
bar13 = api.search_places_by_coordinate("20.645880 -105.23656", "500", "bar")
bar14 = api.search_places_by_coordinate("20.638749 -105.230676", "500", "bar")
bar15 = api.search_places_by_coordinate("20.631444 -105.228353", "500", "bar")
bar16 = api.search_places_by_coordinate("20.624443 -105.227052", "500", "bar")
bar17 = api.search_places_by_coordinate("20.614224 -105.228957", "500", "bar")
bar18 = api.search_places_by_coordinate("20.607962 -105.234626", "500", "bar")
bar19 = api.search_places_by_coordinate("20.602379 -105.235771", "500", "bar")

bar20 = api.search_places_by_coordinate("20.604789 -105.228561", "700", "bar")
bar21 = api.search_places_by_coordinate("20.591934 -105.241779", "1000", "bar")
bar22 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "bar")
bar23 = api.search_places_by_coordinate("20.682131 -105.283878", "1000", "bar")

# %%
bar2df = pd.DataFrame(bar2)
bar3df = pd.DataFrame(bar3)
bar4df = pd.DataFrame(bar4)
bar5df = pd.DataFrame(bar5)
bar6df = pd.DataFrame(bar6)
bar7df = pd.DataFrame(bar7)
bar8df = pd.DataFrame(bar8)
bar9df = pd.DataFrame(bar9)
bar10df = pd.DataFrame(bar10)
bar11df = pd.DataFrame(bar11)
bar12df = pd.DataFrame(bar12)
bar13df = pd.DataFrame(bar13)
bar14df = pd.DataFrame(bar14)
bar15df = pd.DataFrame(bar15)
bar16df = pd.DataFrame(bar16)
bar17df = pd.DataFrame(bar17)
bar18df = pd.DataFrame(bar18)
bar19df = pd.DataFrame(bar19)
bar20df = pd.DataFrame(bar20)
bar21df = pd.DataFrame(bar21)
bar22df = pd.DataFrame(bar22)
bar23df = pd.DataFrame(bar23)

# %%
print(
    bar1df.shape,
    bar2df.shape,
    bar3df.shape,
    bar4df.shape,
    bar5df.shape,
    bar6df.shape,
    bar7df.shape,
    bar8df.shape,
    bar9df.shape,
    bar10df.shape,
    bar11df.shape,
    bar12df.shape,
    bar13df.shape,
    bar14df.shape,
    bar15df.shape,
    bar16df.shape,
    bar17df.shape,
    bar18df.shape,
    bar19df.shape,
    bar20df.shape,
    bar21df.shape,
    bar22df.shape,
    bar23df.shape)
# Out:
# (4, 15) (3, 14) (3, 15) (8, 15) (20, 16) (15, 16) (4, 15) (18, 16) (3, 16) (9, 16) (4, 16) (6, 16) (14, 16) (11, 16) (13, 16) (16, 16) (30, 16) (60, 16) (60, 16) (32, 16) (15, 16) (1, 14) (5, 15)

# %%
bars_basic = pd.concat([bar1df,bar2df,bar3df,bar4df,bar5df,bar6df,bar7df,bar8df,bar9df,bar10df,bar11df,bar12df,
                       bar13df,bar14df,bar15df,bar16df,bar17df,bar18df,bar19df,bar20df,bar21df,bar22df,bar23df,], 
                       ignore_index=True, sort=False)

# %%
bars_basic = bars_basic.drop_duplicates(subset=['place_id'], inplace=False)

# %%
bars_basic.head()
# Out:
#       business_status                                           geometry  \
# 0         OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 1  CLOSED_TEMPORARILY  {'location': {'lat': 20.6944041, 'lng': -105.2...
# 2         OPERATIONAL  {'location': {'lat': 20.6913596, 'lng': -105.2...
# 3  CLOSED_TEMPORARILY  {'location': {'lat': 20.6995215, 'lng': -105.2...
# 4         OPERATIONAL  {'location': {'lat': 20.6240241, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name        opening_hours  \
# 0                                  Claudio's Place   {'open_now': True}
# ...

# %%
bars_basic['place_type'] = "bars"

# %% [markdown]
# ## Art Galleries

# %%
20.669952 -105.2256547

# %%
art_galleries1 = api.search_places_by_coordinate("20.669952 -105.2256547", "10000", "art_gallery")

# %%
art_galleriesdf = pd.DataFrame(art_galleries1)

# %%
art_galleriesdf.shape
# Out:
# (60, 14)

# %%
art_galleriesdf.head(20)
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': 20.6079779, 'lng': -105.2...
# 1      OPERATIONAL  {'location': {'lat': 20.6737328, 'lng': -105.2...
# 2      OPERATIONAL  {'location': {'lat': 20.6108056, 'lng': -105.2...
# 3      OPERATIONAL  {'location': {'lat': 20.6625538, 'lng': -105.2...
# 4      OPERATIONAL  {'location': {'lat': 20.663327, 'lng': -105.24...
# 5      OPERATIONAL  {'location': {'lat': 20.6679293, 'lng': -105.2...
# 6      OPERATIONAL  {'location': {'lat': 20.6894776, 'lng': -105.2...
# 7      OPERATIONAL  {'location': {'lat': 20.6120105, 'lng': -105.2...
# 8      OPERATIONAL  {'location': {'lat': 20.6044329, 'lng': -105.2...
# 9      OPERATIONAL  {'location': {'lat': 20.6141785, 'lng': -105.2...
# 10     OPERATIONAL  {'location': {'lat': 20.6118634, 'lng': -105.2...
# 11     OPERATIONAL  {'location': {'lat': 20.6130335, 'lng': -105.2...
# ...

# %%
art_galleries2 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "art_gallery")

# %%
art_galleries2df = pd.DataFrame(art_galleries2)
print(art_galleries2df.shape)
art_galleries2df.head()
# Out:
# (1, 11)
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.5625161, 'lng': -105.2...
#
#                                                 icon                  name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...  Nogalito Art Gallery
#
#          opening_hours                     place_id  \
# 0  {'open_now': False}  ChIJJWEAIhBbIYQRpMxMCQcvbrw
#
#                                            plus_code  \
# 0  {'compound_code': 'HQ74+2J Puerto Vallarta, Ja...
#
#                      reference   scope  \
# 0  ChIJJWEAIhBbIYQRpMxMCQcvbrw  GOOGLE
#
#                                              types  \
# 0  [art_gallery, point_of_interest, establishment]
#
#                           vicinity
# 0  Calle La Palma 124, El Nogalito

# %%
all_art = pd.concat([art_galleriesdf,art_galleries2df], 
                       ignore_index=True, sort=False)

# %%
all_art = all_art.drop_duplicates(subset=['place_id'], inplace=False)
all_art.shape
# Out:
# (61, 14)

# %%
all_art['place_type'] = "art_gallery"

# %% [markdown]
# ## Casinos

# %%
casinos = api.search_places_by_coordinate("20.669952 -105.2256547", "10000", "casino")

# %%
casinosdf = pd.DataFrame(casinos)
print(casinosdf.shape)
casinosdf.head()
# Out:
# (10, 14)
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6732044, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6583843, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6544444, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6482105, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6145369, 'lng': -105.2...
#
#                                                 icon                  name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...      Lotería Nacional
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...        Emotion Casino
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...  Casino Life Vallarta
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...      Casino en México
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...        Winclub Casino
#
#                       place_id  rating                    reference   scope  \
# ...

# %%
casinos2 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "casino")

# %%
casinos2
# Out:
# []

# %%
casinosdf['place_type'] = "casino"

# %% [markdown]
# ## Gyms

# %%
gyms1 = api.search_places_by_coordinate("20.669952 -105.2256547", "10000", "gym")

# %%
gyms1df = pd.DataFrame(gyms1)
print(gyms1df.shape)
gyms1df.head()
# Out:
# (60, 15)
#       business_status                                           geometry  \
# 0         OPERATIONAL  {'location': {'lat': 20.6144922, 'lng': -105.2...
# 1  CLOSED_TEMPORARILY  {'location': {'lat': 20.6291018, 'lng': -105.2...
# 2  CLOSED_TEMPORARILY  {'location': {'lat': 20.6603359, 'lng': -105.2...
# 3         OPERATIONAL  {'location': {'lat': 20.6558867, 'lng': -105.2...
# 4         OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                 name  \
# 0                                 La Casa del Jardin
# 1                                        Body Action
# ...

# %%
gyms2 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "gym")

# %%
gyms2df = pd.DataFrame(gyms2)
print(gyms2df.shape)
gyms2df.head()
# Out:
# (0, 0)
# Empty DataFrame
# Columns: []
# Index: []

# %%
gyms1df['place_type'] = "gym"

# %% [markdown]
# ## Shopping Malls

# %%
mall1 = api.search_places_by_coordinate("20.669952 -105.2256547", "10000", "shopping_mall")

# %%
mall1df = pd.DataFrame(mall1)
print(mall1df.shape)
mall1df.head(20)
# Out:
# (60, 15)
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 20.6725456, 'lng': -105.2...
# 1          OPERATIONAL  {'location': {'lat': 20.6674137, 'lng': -105.2...
# 2          OPERATIONAL  {'location': {'lat': 20.6607919, 'lng': -105.2...
# 3          OPERATIONAL  {'location': {'lat': 20.6559418, 'lng': -105.2...
# 4          OPERATIONAL  {'location': {'lat': 20.6582935, 'lng': -105.2...
# 5          OPERATIONAL  {'location': {'lat': 20.6545415, 'lng': -105.2...
# 6          OPERATIONAL  {'location': {'lat': 20.6528544, 'lng': -105.2...
# 7          OPERATIONAL  {'location': {'lat': 20.672709, 'lng': -105.25...
# 8          OPERATIONAL  {'location': {'lat': 20.6445603, 'lng': -105.2...
# 9          OPERATIONAL  {'location': {'lat': 20.6401478, 'lng': -105.2...
# 10  CLOSED_TEMPORARILY  {'location': {'lat': 20.6395642, 'lng': -105.2...
# ...

# %%
mall2 = api.search_places_by_coordinate("20.604628 -105.233136", "2000", "shopping_mall")
mall3 = api.search_places_by_coordinate("20.629063 -105.227048", "2000", "shopping_mall")
mall4 = api.search_places_by_coordinate("20.655552, -105.235572", "3000", "shopping_mall")
mall5 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "shopping_mall")

# %%
mall2df = pd.DataFrame(mall2)
mall3df = pd.DataFrame(mall3)
mall4df = pd.DataFrame(mall4)
mall5df = pd.DataFrame(mall5)

# %%
print(mall2df.shape, mall3df.shape, mall4df.shape, mall5df.shape)
# Out:
# (20, 14) (31, 15) (60, 15) (1, 14)

# %%
all_malls = pd.concat([mall1df, mall2df, mall3df, mall4df, mall5df], 
                       ignore_index=True, sort=False)

# %%
all_malls = all_malls.drop_duplicates(subset=['place_id'], inplace=False)

# %%
all_malls['place_type'] = "shopping_mall"

# %% [markdown]
# ## Supermarkets:

# %%
supermarket1 = api.search_places_by_coordinate("20.669952 -105.2256547", "10000", "supermarket")

# %%
supermarket1df = pd.DataFrame(supermarket1)
print(supermarket1df.shape)
supermarket1df.head(20)
# Out:
# (60, 16)
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 20.6446857, 'lng': -105.2...
# 1          OPERATIONAL  {'location': {'lat': 20.7224574, 'lng': -105.2...
# 2          OPERATIONAL  {'location': {'lat': 20.6647579, 'lng': -105.2...
# 3          OPERATIONAL  {'location': {'lat': 20.6542465, 'lng': -105.2...
# 4          OPERATIONAL  {'location': {'lat': 20.678259, 'lng': -105.22...
# 5          OPERATIONAL  {'location': {'lat': 20.6680574, 'lng': -105.2...
# 6          OPERATIONAL  {'location': {'lat': 20.6615444, 'lng': -105.2...
# 7          OPERATIONAL  {'location': {'lat': 20.670307, 'lng': -105.21...
# 8          OPERATIONAL  {'location': {'lat': 20.6895789, 'lng': -105.2...
# 9          OPERATIONAL  {'location': {'lat': 20.6757136, 'lng': -105.2...
# 10         OPERATIONAL  {'location': {'lat': 20.668128, 'lng': -105.24...
# ...

# %%
supermarket2 = api.search_places_by_coordinate("20.604628 -105.233136", "2000", "supermarket")
supermarket3 = api.search_places_by_coordinate("20.629063 -105.227048", "2000", "supermarket")
supermarket4 = api.search_places_by_coordinate("20.655552, -105.235572", "3000", "supermarket")
supermarket5 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "supermarket")

# %%
supermarket2df = pd.DataFrame(supermarket2)
supermarket3df = pd.DataFrame(supermarket3)
supermarket4df = pd.DataFrame(supermarket4)
supermarket5df = pd.DataFrame(supermarket5)

# %%
supermarket5df.shape
# Out:
# (0, 0)

# %%
all_supermarkets = pd.concat([supermarket1df, supermarket2df, supermarket3df, supermarket4df, supermarket5df], 
                       ignore_index=True, sort=False)

# %%
all_supermarkets = all_supermarkets.drop_duplicates(subset=['place_id'], inplace=False)

# %%
all_supermarkets['place_type'] = "super_market"

# %% [markdown]
# ## Tourist Attractions:

# %%
tour1 = api.search_places_by_coordinate("20.604628 -105.233136", "2000", "tourist_attraction")
tour2 = api.search_places_by_coordinate("20.629063 -105.227048", "2000", "tourist_attraction")
tour3 = api.search_places_by_coordinate("20.655552, -105.235572", "3000", "tourist_attraction")
tour4 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "tourist_attraction")

# %%
tour1df = pd.DataFrame(tour1)
tour2df = pd.DataFrame(tour2)
tour3df = pd.DataFrame(tour3)
tour4df = pd.DataFrame(tour4)
print(tour1df.shape, tour2df.shape, tour3df.shape, tour4df.shape)
# Out:
# (42, 15) (9, 14) (17, 14) (10, 14)

# %%
all_attractions = pd.concat([tour1df, tour2df, tour3df, tour4df], 
                       ignore_index=True, sort=False)

# %%
all_attractions = all_attractions.drop_duplicates(subset=['place_id'], inplace=False)

# %%
all_attractions['place_type'] = "tourist_attraction"

# %% [markdown]
# ## Combine All "Other" Places (not lodging/hotels):

# %%
all_places = pd.concat([restaurants_basic, bars_basic, all_art, casinosdf, gyms1df, all_malls,
                       all_supermarkets, all_attractions],
                       ignore_index=True, sort=False)

# %%
all_places.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6938154, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6917245, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6919927, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6898023, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                            name       opening_hours  \
# 0                               Claudio's Place  {'open_now': True}
# 1                The Blue Shrimp Nuevo Vallarta  {'open_now': True}
# ...

# %%
all_places.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count             1703                                               1705
# unique               2                                               1568
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq              1588                                                  9
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon  \
# ...

# %%
all_places.shape
# Out:
# (1705, 17)

# %%
all_places.columns
# Out:
# Index(['business_status', 'geometry', 'icon', 'name', 'opening_hours',
#        'photos', 'place_id', 'plus_code', 'rating', 'reference', 'scope',
#        'types', 'user_ratings_total', 'vicinity', 'price_level',
#        'permanently_closed', 'place_type'],
#       dtype='object')

# %%
all_places = all_places[all_places['business_status']=="OPERATIONAL"]

# %%
all_places.shape
# Out:
# (1588, 17)

# %%
all_places = all_places.drop(columns=['icon','opening_hours','photos','plus_code','reference','scope','price_level'])

# %%
all_places.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count             1588                                               1588
# unique               1                                               1460
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq              1588                                                  8
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                              name                     place_id       rating  \
# ...

# %%
all_places.to_csv(r'all_places.csv', index=True, header=True, index_label=False)
