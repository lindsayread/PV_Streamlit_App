# %%
import requests
import json
import time

import pandas as pd
from googletrans import Translator, constants
from pprint import pprint

# %%
class GooglePlaces(object):
    def __init__(self, apiKey):
        super(GooglePlaces, self).__init__()
        self.apiKey = apiKey
        
    def search_places_by_coordinate(self, location, radius, types):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        places = []
        params = {
            'location': location,
            'radius': radius,
            'types': types,
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        results =  json.loads(res.content)
        places.extend(results['results'])
        time.sleep(2)
        while "next_page_token" in results:
            params['pagetoken'] = results['next_page_token'],
            res = requests.get(endpoint_url, params = params)
            results = json.loads(res.content)
            places.extend(results['results'])
            time.sleep(2)
        return places
    
    def get_place_details(self, place_id, fields):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/details/json"
        params = {
            'placeid': place_id,
            'fields': ",".join(fields),
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        place_details =  json.loads(res.content)
        return place_details

# %%
api = GooglePlaces("AIzaSyAVGW0SZpsJgHMsdW2jYOOfm-iEzY2oKIY")

# %%
coordinates = ["20.691042 -105.275793",
              "20.623661 -105.221570",
              "20.632749 -105.221477",
              "20.641054 -105.221291",
              "20.650576 -105.219386",
              "20.655880 -105.227471",
              "20.674095 -105.248472",
              "20.668400 -105.249680",
              "20.664922 -105.257299",
              "20.661314 -105.249726",
              "20.661401 -105.233046",
              "20.653401 -105.238575",
              "20.645880 -105.23656",
              "20.638749 -105.230676",
              "20.631444 -105.228353",
              "20.624443 -105.227052",
              "20.614224 -105.228957",
              "20.607962 -105.234626",
              "20.602379 -105.235771"]

# %%
pv1 = api.search_places_by_coordinate("20.691042 -105.275793", "500", "lodging")
pv1[0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 20.6939009, 'lng': -105.2742384},
#   'viewport': {'northeast': {'lat': 20.6952584802915,
#     'lng': -105.2728624197085},
#    'southwest': {'lat': 20.6925605197085, 'lng': -105.2755603802915}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#  'name': 'casa LAS PIÑAS',
#  'opening_hours': {'open_now': False},
#  'photos': [{'height': 640,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105326007196807331575">casa LAS PIÑAS</a>'],
#    'photo_reference': 'CkQ0AAAAydWkmQBEavP9YyTH4PWyD7Nr9mr8FY5lH8ZK_NtC6YPeGuxKm9v_vmPBbv_D3dCjLKgU8nHs1Y4hnP62ZaSQkxIQ7fq8fSPwutw9cpHCMLgm2BoUeWjLW_9P68z6YpcLqC0AV9zxf9k',
#    'width': 960}],
#  'place_id': 'ChIJIeVYvYNGIYQRh-9bPVK3fCU',
#  'plus_code': {'compound_code': 'MPVG+H8 Jarretaderas, Nayarit, Mexico',
#   'global_code': '75GPMPVG+H8'},
#  'rating': 4.6,
#  'reference': 'ChIJIeVYvYNGIYQRh-9bPVK3fCU',
# ...

# %%
pv1df = pd.DataFrame(pv1)
pv1df.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.689785, 'lng': -105.27...
# 3     OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6938115, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                    name        opening_hours  \
# 0                        casa LAS PIÑAS  {'open_now': False}
# 1  Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
pv2 = api.search_places_by_coordinate("20.623661 -105.221570", "500", "lodging")
pv3 = api.search_places_by_coordinate("20.632749 -105.221477", "500", "lodging")
pv4 = api.search_places_by_coordinate("20.641054 -105.221291", "500", "lodging")
pv5 = api.search_places_by_coordinate("20.650576 -105.219386", "500", "lodging")
pv6 = api.search_places_by_coordinate("20.655880 -105.227471", "500", "lodging")
pv7 = api.search_places_by_coordinate("20.674095 -105.248472", "500", "lodging")
pv8 = api.search_places_by_coordinate("20.668400 -105.249680", "500", "lodging")
pv9 = api.search_places_by_coordinate("20.664922 -105.257299", "500", "lodging")
pv10 = api.search_places_by_coordinate("20.661314 -105.249726", "500", "lodging")
pv11 = api.search_places_by_coordinate("20.661401 -105.233046", "500", "lodging")
pv12 = api.search_places_by_coordinate("20.653401 -105.238575", "500", "lodging")
pv13 = api.search_places_by_coordinate("20.645880 -105.23656", "500", "lodging")
pv14 = api.search_places_by_coordinate("20.638749 -105.230676", "500", "lodging")
pv15 = api.search_places_by_coordinate("20.631444 -105.228353", "500", "lodging")
pv16 = api.search_places_by_coordinate("20.624443 -105.227052", "500", "lodging")
pv17 = api.search_places_by_coordinate("20.614224 -105.228957", "500", "lodging")
pv18 = api.search_places_by_coordinate("20.607962 -105.234626", "500", "lodging")
pv19 = api.search_places_by_coordinate("20.602379 -105.235771", "500", "lodging")

pv20 = api.search_places_by_coordinate("20.604789 -105.228561", "700", "lodging")
pv21 = api.search_places_by_coordinate("20.591934 -105.241779", "1000", "lodging")
pv22 = api.search_places_by_coordinate("20.556099 -105.259240", "4000", "lodging")
pv23 = api.search_places_by_coordinate("20.682131 -105.283878", "1000", "lodging")

# %%
pv2df = pd.DataFrame(pv2)
pv3df = pd.DataFrame(pv3)
pv4df = pd.DataFrame(pv4)
pv5df = pd.DataFrame(pv5)
pv6df = pd.DataFrame(pv6)
pv7df = pd.DataFrame(pv7)
pv8df = pd.DataFrame(pv8)
pv9df = pd.DataFrame(pv9)
pv10df = pd.DataFrame(pv10)
pv11df = pd.DataFrame(pv11)
pv12df = pd.DataFrame(pv12)
pv13df = pd.DataFrame(pv13)
pv14df = pd.DataFrame(pv14)
pv15df = pd.DataFrame(pv15)
pv16df = pd.DataFrame(pv16)
pv17df = pd.DataFrame(pv17)
pv18df = pd.DataFrame(pv18)
pv19df = pd.DataFrame(pv19)
pv20df = pd.DataFrame(pv20)
pv21df = pd.DataFrame(pv21)
pv22df = pd.DataFrame(pv22)
pv23df = pd.DataFrame(pv23)

# %%
print(
    pv1df.shape,
    pv2df.shape,
    pv3df.shape,
    pv4df.shape,
    pv5df.shape,
    pv6df.shape,
    pv7df.shape,
    pv8df.shape,
    pv9df.shape,
    pv10df.shape,
    pv11df.shape,
    pv12df.shape,
    pv13df.shape,
    pv14df.shape,
    pv15df.shape,
    pv16df.shape,
    pv17df.shape,
    pv18df.shape,
    pv19df.shape,
    pv20df.shape,
    pv21df.shape,
    pv22df.shape,
    pv23df.shape)
# Out:
# (5, 14) (10, 14) (14, 14) (6, 14) (19, 14) (37, 14) (19, 14) (22, 14) (24, 14) (30, 14) (13, 14) (20, 14) (30, 14) (35, 14) (44, 14) (23, 14) (59, 14) (60, 14) (60, 15) (60, 15) (60, 14) (60, 14) (33, 14)

# %%
pv1df.columns
# Out:
# Index(['business_status', 'geometry', 'icon', 'name', 'opening_hours',
#        'photos', 'place_id', 'plus_code', 'rating', 'reference', 'scope',
#        'types', 'user_ratings_total', 'vicinity'],
#       dtype='object')

# %%
pv19df_fix = pv19df.drop(columns=['price_level'])

# %%
pv20df_fix = pv20df.drop(columns=['price_level'])

# %%
hotels_basic = pd.concat([pv1df,pv2df,pv3df,pv4df,pv5df,pv6df,pv7df,pv8df,pv9df,pv10df,pv11df,pv12df,
                       pv13df,pv14df,pv15df,pv16df,pv17df,pv18df,pv19df,pv20df,pv21df,pv22df,pv23df,], 
                       ignore_index=True, sort=False)

# %%
hotels_basic.shape
# Out:
# (743, 15)

# %%
places[0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 20.6262325, 'lng': -105.2311828},
#   'viewport': {'northeast': {'lat': 20.6276914302915,
#     'lng': -105.2296212697085},
#    'southwest': {'lat': 20.6249934697085, 'lng': -105.2323192302915}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#  'name': 'Sheraton Buganvilias Resort & Convention Center',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 810,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117556152708526272060">Sheraton Buganvilias Resort &amp; Convention Center</a>'],
#    'photo_reference': 'CkQ0AAAAnyxso00i7obBShQESFb7G_JoeOVoi5eqchO7VNo7sCI6gozBamUWcvLUgpqOkOoy25APeihR9XzuPun6_IQXwxIQBz0VMi9ZVbqN0f69TkEKaxoUHXAtsvHwMbzkvZGdPbxgPecuRAk',
#    'width': 1440}],
#  'place_id': 'ChIJtRVgz2dFIYQR6Q0Wx8EHtzw',
#  'plus_code': {'compound_code': 'JQG9+FG Puerto Vallarta, Jalisco, Mexico',
#   'global_code': '75GPJQG9+FG'},
# ...

# %%
df1 = pd.DataFrame(places)
df1
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': 20.6262325, 'lng': -105.2...
# 1      OPERATIONAL  {'location': {'lat': 20.6209517, 'lng': -105.2...
# 2      OPERATIONAL  {'location': {'lat': 20.6280574, 'lng': -105.2...
# 3      OPERATIONAL  {'location': {'lat': 20.6201691, 'lng': -105.2...
# 4      OPERATIONAL  {'location': {'lat': 20.6251269, 'lng': -105.2...
# 5      OPERATIONAL  {'location': {'lat': 20.62219, 'lng': -105.231...
# 6      OPERATIONAL  {'location': {'lat': 20.6211053, 'lng': -105.2...
# 7      OPERATIONAL  {'location': {'lat': 20.6217528, 'lng': -105.2...
# 8      OPERATIONAL  {'location': {'lat': 20.6217146, 'lng': -105.2...
# 9      OPERATIONAL  {'location': {'lat': 20.6261008, 'lng': -105.2...
# 10     OPERATIONAL  {'location': {'lat': 20.6264929, 'lng': -105.2...
# 11     OPERATIONAL  {'location': {'lat': 20.6214084, 'lng': -105.2...
# ...

# %%
def translated_place_details(places):
    list6 = []
    for place in places:
        details = api.get_place_details(place['place_id'], fields)
        try:
            result_details = details['result']
        except KeyError:
            result_details = ""

        result_details['place_id'] = place['place_id']

        customer_reviews = []
        text_reviews = []

        try:
            reviews = details['result']['reviews']
        except:
            reviews = ""

        for review in reviews:
            customer_reviews.append(review['rating'])

            translator = Translator()
            translated = translator.translate(review['text'])
            text_reviews.append(translated.text)

        result_details['all_ratings'] = customer_reviews
        result_details['all_reviews'] = text_reviews

        list6.append(result_details)
    return list6

# %%
fields = ['name','rating','international_phone_number', 'website', 'rating', 'review','price_level','user_ratings_total']

# %%
detailspv1 = translated_place_details(pv1)
detailspv1df = pd.DataFrame(detailspv1)

# %%
detailspv1df.head()
# Out:
#   international_phone_number                                  name  rating  \
# 0           +52 322 102 8516                        casa LAS PIÑAS     4.6
# 1           +52 322 297 0093  Villas Victoria Confort Jarretaderas     5.0
# 2            +57 301 4649339                       Lada telefonica     NaN
# 3           +52 322 135 6145                Hotel Posada Alejandra     4.0
# 4                        NaN                        casa LAS PIÑAS     NaN
#
#                                              reviews  user_ratings_total  \
# 0  [{'author_name': 'Jovita Garcia Fernandez', 'a...                 8.0
# 1  [{'author_name': 'anahi chavez', 'author_url':...                 1.0
# 2                                                NaN                 NaN
# 3  [{'author_name': 'Juan Carlos Lopez', 'author_...                54.0
# 4                                                NaN                 NaN
#
#                                              website  \
# ...

# %%
detailspv2 = translated_place_details(pv2)
detailspv2df = pd.DataFrame(detailspv2)

detailspv3 = translated_place_details(pv3)
detailspv3df = pd.DataFrame(detailspv3)

detailspv4 = translated_place_details(pv4)
detailspv4df = pd.DataFrame(detailspv4)

detailspv5 = translated_place_details(pv5)
detailspv5df = pd.DataFrame(detailspv5)

detailspv6 = translated_place_details(pv6)
detailspv6df = pd.DataFrame(detailspv6)

detailspv7 = translated_place_details(pv7)
detailspv7df = pd.DataFrame(detailspv7)

detailspv8 = translated_place_details(pv8)
detailspv8df = pd.DataFrame(detailspv8)

detailspv9 = translated_place_details(pv9)
detailspv9df = pd.DataFrame(detailspv9)

detailspv10 = translated_place_details(pv10)
detailspv10df = pd.DataFrame(detailspv10)

detailspv11 = translated_place_details(pv11)
detailspv11df = pd.DataFrame(detailspv11)

detailspv12 = translated_place_details(pv12)
detailspv12df = pd.DataFrame(detailspv12)

detailspv13 = translated_place_details(pv13)
detailspv13df = pd.DataFrame(detailspv13)

detailspv14 = translated_place_details(pv14)
detailspv14df = pd.DataFrame(detailspv14)

detailspv15 = translated_place_details(pv15)
detailspv15df = pd.DataFrame(detailspv15)

detailspv16 = translated_place_details(pv16)
detailspv16df = pd.DataFrame(detailspv16)

detailspv17 = translated_place_details(pv17)
detailspv17df = pd.DataFrame(detailspv17)

detailspv18 = translated_place_details(pv18)
detailspv18df = pd.DataFrame(detailspv18)

detailspv19 = translated_place_details(pv19)
detailspv19df = pd.DataFrame(detailspv19)

detailspv20 = translated_place_details(pv20)
detailspv20df = pd.DataFrame(detailspv20)

detailspv21 = translated_place_details(pv21)
detailspv21df = pd.DataFrame(detailspv21)

detailspv22 = translated_place_details(pv22)
detailspv22df = pd.DataFrame(detailspv22)

detailspv23 = translated_place_details(pv23)
detailspv23df = pd.DataFrame(detailspv23)

# %%
print(
    detailspv1df.shape,
    detailspv2df.shape,
    detailspv3df.shape,
    detailspv4df.shape,
    detailspv5df.shape,
    detailspv6df.shape,
    detailspv7df.shape,
    detailspv8df.shape,
    detailspv9df.shape,
    detailspv10df.shape,
    detailspv11df.shape,
    detailspv12df.shape,
    detailspv13df.shape,
    detailspv14df.shape,
    detailspv15df.shape,
    detailspv16df.shape,
    detailspv17df.shape,
    detailspv18df.shape,
    detailspv19df.shape,
    detailspv20df.shape,
    detailspv21df.shape,
    detailspv22df.shape,
    detailspv23df.shape)
# Out:
# (5, 9) (10, 9) (14, 9) (6, 8) (19, 9) (37, 9) (19, 9) (22, 9) (24, 9) (30, 9) (13, 9) (20, 9) (30, 9) (35, 9) (44, 9) (23, 9) (59, 9) (60, 9) (60, 10) (60, 10) (60, 9) (60, 9) (33, 9)

# %%
detailspv3df.columns
# Out:
# Index(['international_phone_number', 'name', 'rating', 'reviews',
#        'user_ratings_total', 'place_id', 'all_ratings', 'all_reviews',
#        'website'],
#       dtype='object')

# %%
detailspv4df.columns # doesnt have website
# Out:
# Index(['international_phone_number', 'name', 'place_id', 'all_ratings',
#        'all_reviews', 'rating', 'reviews', 'user_ratings_total'],
#       dtype='object')

# %%
detailspv4df['website'] = ""
detailspv4df.head()
# Out:
#   international_phone_number                   name  \
# 0           +52 322 136 1311           Villa Paloma
# 1           +52 322 151 6119        Casa de Ambrose
# 2           +52 644 230 8220           Casa Pavlova
# 3                        NaN  D’Cora suite Vallarta
# 4           +52 871 111 5995          Depa vallarta
#
#                       place_id      all_ratings  \
# 0  ChIJAQBsPYdPIYQRZUSPVR2NrBM               []
# 1  ChIJ235toodPIYQR5p5YsYiRf2c  [5, 5, 4, 5, 5]
# 2  ChIJE1Gk_51PIYQRIT-VcCHWLa4        [5, 5, 4]
# 3  ChIJ3V_DKAlFIYQREVvv8wnGwR4               []
# 4  ChIJGeUor59FIYQRJ4VgrqfrkuU              [5]
#
#                                          all_reviews  rating  \
# 0                                                 []     NaN
# 1  [Can someone tell me how to contact the hotel?...     4.8
# 2                                             [, , ]     4.7
# 3                                                 []     NaN
# ...

# %%
detailspv19df.columns # price_level is not on other dfs
# Out:
# Index(['international_phone_number', 'name', 'rating', 'reviews',
#        'user_ratings_total', 'website', 'place_id', 'all_ratings',
#        'all_reviews', 'price_level'],
#       dtype='object')

# %%
detailspv19df_fix = detailspv19df.drop(columns=['price_level'])

# %%
detailspv20df.columns # price_level is not on other dfs
# Out:
# Index(['international_phone_number', 'name', 'rating', 'reviews',
#        'user_ratings_total', 'website', 'place_id', 'all_ratings',
#        'all_reviews', 'price_level'],
#       dtype='object')

# %%
detailspv20df_fix = detailspv20df.drop(columns=['price_level'])

# %% [markdown]
# ## Append All Detail DataFrames into One DF:

# %%
all_details = pd.concat([detailspv1df,detailspv2df,detailspv3df,detailspv4df,detailspv5df,
                        detailspv6df,detailspv7df,detailspv8df,detailspv9df,detailspv10df,
                        detailspv11df,detailspv12df,detailspv13df,detailspv14df,detailspv15df,
                        detailspv16df,detailspv17df,detailspv18df,detailspv19df,detailspv20df,
                        detailspv21df,detailspv22df,detailspv23df], ignore_index=True, sort=False)

# %%
all_details.shape
# Out:
# (743, 10)

# %% [markdown]
# ## Merge Basic Details with All Details:

# %%
all_info = pd.merge(hotels_basic, all_details, on='place_id')

# %%
all_info.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.689785, 'lng': -105.27...
# 3     OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6938115, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                  name_x        opening_hours  \
# 0                        casa LAS PIÑAS  {'open_now': False}
# 1  Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
all_info.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'dict'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'dict'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'dict'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
# ...

# %%
all_info.to_csv(r'hotel_info.csv', index=True, header=True, index_label=False)
