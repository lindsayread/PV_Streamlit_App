# %%
import pandas as pd
import numpy as np

# %%
other = pd.read_csv('all_places.csv')
other.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6938154, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6917245, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6919927, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6898023, 'lng': -105.2...
#
#                                            name                     place_id  \
# 0                               Claudio's Place  ChIJMUwQD51GIYQRJgins7Zd2Vg
# 1                The Blue Shrimp Nuevo Vallarta  ChIJPVj2k5xGIYQRhuGhW6K4srg
# 2                                        Quesos  ChIJyR1UOQtHIYQRjkhFEnVI5-4
# 3  Los Charales de Jarretaderas, Estilo Chileno  ChIJm9JDz1ZHIYQRQcr5yofPgYs
# 4                                        Pozole  ChIJdbFx-TxHIYQRDJDMm8D7mSM
#
#    rating                                              types  \
# ...

# %%
other = other.drop(columns=['permanently_closed'])

# %%
other['geometry'] = other['geometry'].str.split(", 'v").str[0]

other['geometry'] = other['geometry'].str.split("location': ").str[1]

other.iloc[0].geometry
# Out:
# "{'lat': 20.6911818, 'lng': -105.2804769}"

# %%
df_geo = other['geometry'].map(eval).apply(pd.Series)

df_geo.head()
# Out:
#          lat         lng
# 0  20.691182 -105.280477
# 1  20.693815 -105.279836
# 2  20.691724 -105.274816
# 3  20.691993 -105.274341
# 4  20.689802 -105.277280

# %%
other = other.merge(df_geo, how='outer', left_index=True, right_index=True)
other.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6911818, 'lng': -105.2804769}
# 1     OPERATIONAL  {'lat': 20.6938154, 'lng': -105.2798356}
# 2     OPERATIONAL  {'lat': 20.6917245, 'lng': -105.2748159}
# 3     OPERATIONAL  {'lat': 20.6919927, 'lng': -105.2743408}
# 4     OPERATIONAL    {'lat': 20.6898023, 'lng': -105.27728}
#
#                                            name                     place_id  \
# 0                               Claudio's Place  ChIJMUwQD51GIYQRJgins7Zd2Vg
# 1                The Blue Shrimp Nuevo Vallarta  ChIJPVj2k5xGIYQRhuGhW6K4srg
# 2                                        Quesos  ChIJyR1UOQtHIYQRjkhFEnVI5-4
# 3  Los Charales de Jarretaderas, Estilo Chileno  ChIJm9JDz1ZHIYQRQcr5yofPgYs
# 4                                        Pozole  ChIJdbFx-TxHIYQRDJDMm8D7mSM
#
#    rating                                              types  \
# 0     4.4  ['bar', 'restaurant', 'food', 'point_of_intere...
# ...

# %%
other.describe(include='all')
# Out:
#        business_status                                         geometry  \
# count             1588                                             1588
# unique               1                                             1457
# top        OPERATIONAL  {'lat': 20.65340699999999, 'lng': -105.2253316}
# freq              1588                                                8
# mean               NaN                                              NaN
# std                NaN                                              NaN
# min                NaN                                              NaN
# 25%                NaN                                              NaN
# 50%                NaN                                              NaN
# 75%                NaN                                              NaN
# max                NaN                                              NaN
#
#                              name                     place_id       rating  \
# ...

# %%
other.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6911818, 'lng': -105.2804769}
# 1     OPERATIONAL  {'lat': 20.6938154, 'lng': -105.2798356}
# 2     OPERATIONAL  {'lat': 20.6917245, 'lng': -105.2748159}
# 3     OPERATIONAL  {'lat': 20.6919927, 'lng': -105.2743408}
# 4     OPERATIONAL    {'lat': 20.6898023, 'lng': -105.27728}
#
#                                            name                     place_id  \
# 0                               Claudio's Place  ChIJMUwQD51GIYQRJgins7Zd2Vg
# 1                The Blue Shrimp Nuevo Vallarta  ChIJPVj2k5xGIYQRhuGhW6K4srg
# 2                                        Quesos  ChIJyR1UOQtHIYQRjkhFEnVI5-4
# 3  Los Charales de Jarretaderas, Estilo Chileno  ChIJm9JDz1ZHIYQRQcr5yofPgYs
# 4                                        Pozole  ChIJdbFx-TxHIYQRDJDMm8D7mSM
#
#    rating                                              types  \
# 0     4.4  ['bar', 'restaurant', 'food', 'point_of_intere...
# ...

# %%
rated_places = other[other['rating'].notnull()]

# %%
rated_places.describe(include='all')
# Out:
#        business_status                                         geometry  \
# count             1303                                             1303
# unique               1                                             1191
# top        OPERATIONAL  {'lat': 20.63811859999999, 'lng': -105.2217454}
# freq              1303                                                5
# mean               NaN                                              NaN
# std                NaN                                              NaN
# min                NaN                                              NaN
# 25%                NaN                                              NaN
# 50%                NaN                                              NaN
# 75%                NaN                                              NaN
# max                NaN                                              NaN
#
#                              name                     place_id       rating  \
# ...

# %%
rated_places = rated_places[rated_places['rating']>3]

# %%
rated_places.shape
# Out:
# (1279, 11)

# %%
from itertools import product

# %%
rated_places.dtypes
# Out:
# business_status        object
# geometry               object
# name                   object
# place_id               object
# rating                float64
# types                  object
# user_ratings_total    float64
# vicinity               object
# place_type             object
# lat                   float64
# lng                   float64
# long_lat              float64
# dtype: object

# %%
rated_places['lng'] = rated_places['lng'].astype(str)
rated_places['lat'] = rated_places['lat'].astype(str)

# %%
rated_places['long_lat'] = rated_places['lng'].str.cat(rated_places['lat'],sep=", ")
rated_places.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6911818, 'lng': -105.2804769}
# 1     OPERATIONAL  {'lat': 20.6938154, 'lng': -105.2798356}
# 5     OPERATIONAL   {'lat': 20.6931104, 'lng': -105.274536}
# 6     OPERATIONAL  {'lat': 20.6921476, 'lng': -105.2733732}
# 7     OPERATIONAL  {'lat': 20.6891107, 'lng': -105.2740624}
#
#                              name                     place_id  rating  \
# 0                 Claudio's Place  ChIJMUwQD51GIYQRJgins7Zd2Vg     4.4
# 1  The Blue Shrimp Nuevo Vallarta  ChIJPVj2k5xGIYQRhuGhW6K4srg     4.5
# 5     BLUE TARP RESTAURANT - MAGO  ChIJsSQDhrlHIYQRBlq2Z9h6zsU     5.0
# 6             Menuderia doña cuca  ChIJOet8NYJGIYQR-pCCv3wGmZY     4.3
# 7    Fonda La Casa De Los Abuelos  ChIJJejZZSVFIYQRWg7Wfn0HlM0     4.0
#
#                                                types  user_ratings_total  \
# 0  ['bar', 'restaurant', 'food', 'point_of_intere...               111.0
# ...

# %%
restaurants = rated_places[rated_places['place_type']=='restaurant']
restaurants.shape
# Out:
# (788, 12)

# %% [markdown]
# # List Number of Places within Walking Distance for Each Hotel:

# %%
hotels = pd.read_csv('hotels_cleaned.csv')

# %%
hotels['lng'] = hotels['lng'].astype(str)
hotels['lat'] = hotels['lat'].astype(str)

# %%
hotels['long_lat'] = hotels['lng'].str.cat(hotels['lat'],sep=", ")
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
haversine_np(hotels['lng'], hotels['lat'], )

# %%
counter_rest = 0
restaurant_names = []
for i in restaurants:
    if haversine_np <= 1:
        counter += 1
        restaurant_names.append(rest)
    else:
        pass

# %%
rated_places['lng'] = rated_places['lng'].astype(float)
rated_places['lat'] = rated_places['lat'].astype(float)

hotels['lng'] = hotels['lng'].astype(float)
hotels['lat'] = hotels['lat'].astype(float)

# %%
restaurants.iloc[0].lat
# Out:
# 20.6911818

# %%
-105.2742384, 20.6939009,

# %%
hotels['num_close_restaurants'] = haversine_np(hotels.iloc[0].lng, hotels.iloc[0].lat, restaurants.iloc[0].lng, restaurants.iloc[0].lat)

# %%
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
hotels['name_restaurants'] =

# %%
haversine_np(-105.243460, 20.562397, -105.234347, 20.611905) <= 1
# Out:
# False

# %%
haversine_np(-105.243460, 20.562397, -105.234347, 20.611905)
# Out:
# 5.582663497695923

# %%
count = 0
if distance <= 1000:

# %%
station_locations['Distance to Columbia'] = haversine_np(station_locations['Station Longitude'],
                                             station_locations['Station Latitude'],
                                             station_locations['Columbia Longitude'],
                                             station_locations['Columbia Latitude'])
