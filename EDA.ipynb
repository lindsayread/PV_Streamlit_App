# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_info.csv')

# %%
df.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.689785, 'lng': -105.27...
# 3     OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6938115, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                  name_x        opening_hours  \
# 0                        casa LAS PIÑAS  {'open_now': False}
# 1  Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
df.shape
# Out:
# (955, 24)

# %%
df.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              955                                                955
# unique               1                                                614
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               955                                                 23
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon          name_x  \
# ...

# %%
df1 = df.drop_duplicates(subset=['place_id'], inplace=False)

# %%
df1.shape
# Out:
# (646, 24)

# %%
df1.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              646                                                646
# unique               1                                                614
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               646                                                 23
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon           name_x  \
# ...

# %%
df1.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.689785, 'lng': -105.27...
# 3     OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6938115, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                  name_x        opening_hours  \
# 0                        casa LAS PIÑAS  {'open_now': False}
# 1  Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
df1 = df1[df1['all_reviews']!="[]"]

# %%
df1.shape
# Out:
# (442, 24)

# %%
df1.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 5     OPERATIONAL  {'location': {'lat': 20.6241471, 'lng': -105.2...
# 9     OPERATIONAL  {'location': {'lat': 20.6225929, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
df1 = df1.reset_index(drop=True)

# %%
df1.shape
# Out:
# (442, 24)

# %%
df1.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6241471, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6225929, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
df1.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              442                                                442
# unique               1                                                436
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               442                                                  6
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon              name_x  \
# ...

# %%
df1 = df1[df1['all_reviews']!="['']"]

# %%
df1.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              403                                                403
# unique               1                                                399
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               403                                                  4
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon           name_x  \
# ...

# %%
df1 = df1[df1['all_reviews']!="['', '']"]

# %%
df1.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              395                                                395
# unique               1                                                392
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               395                                                  3
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon  \
# ...

# %%
df1 = df1[df1['all_reviews']!="['', '', '']"]

# %%
df1.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              392                                                392
# unique               1                                                389
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               392                                                  3
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon  \
# ...

# %%
df1 = df1[df1['all_reviews']!="['', '', '', '']"]

# %%
df1.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              389                                                389
# unique               1                                                386
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               389                                                  3
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon        name_x  \
# ...

# %%
df1 = df1[df1['all_reviews']!="['Good']"]

# %%
df1.describe(include='all')
# Out:
#        business_status                                           geometry  \
# count              387                                                387
# unique               1                                                384
# top        OPERATIONAL  {'location': {'lat': 20.65340699999999, 'lng':...
# freq               387                                                  3
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#                                                      icon        name_x  \
# ...

# %%
df1.head(20)
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1      OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 2      OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 3      OPERATIONAL  {'location': {'lat': 20.6241471, 'lng': -105.2...
# 4      OPERATIONAL  {'location': {'lat': 20.6225929, 'lng': -105.2...
# 5      OPERATIONAL  {'location': {'lat': 20.6272548, 'lng': -105.2...
# 6      OPERATIONAL  {'location': {'lat': 20.6221949, 'lng': -105.2...
# 7      OPERATIONAL  {'location': {'lat': 20.6254901, 'lng': -105.2...
# 8      OPERATIONAL  {'location': {'lat': 20.6208631, 'lng': -105.2...
# 9      OPERATIONAL  {'location': {'lat': 20.6267224, 'lng': -105.2...
# 10     OPERATIONAL  {'location': {'lat': 20.627761, 'lng': -105.22...
# 11     OPERATIONAL  {'location': {'lat': 20.6349484, 'lng': -105.2...
# ...

# %%
df1 = df1.reset_index(drop=True)
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6939009, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6920731, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6939068, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6241471, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6225929, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
df1['geometry'] = df1['geometry'].str.split(", 'v").str[0]

# %%
df1['geometry'] = df1['geometry'].str.split("location': ").str[1]

# %%
df1.iloc[0].geometry
# Out:
# "{'lat': 20.6939009, 'lng': -105.2742384}"

# %%
df1
# Out:
#     business_status                                         geometry  \
# 0       OPERATIONAL         {'lat': 20.6939009, 'lng': -105.2742384}
# 1       OPERATIONAL         {'lat': 20.6920731, 'lng': -105.2747303}
# 2       OPERATIONAL         {'lat': 20.6939068, 'lng': -105.2763239}
# 3       OPERATIONAL         {'lat': 20.6241471, 'lng': -105.2243218}
# 4       OPERATIONAL         {'lat': 20.6225929, 'lng': -105.2232518}
# ..              ...                                              ...
# 382     OPERATIONAL          {'lat': 20.6769383, 'lng': -105.285772}
# 383     OPERATIONAL         {'lat': 20.6837179, 'lng': -105.2898603}
# 384     OPERATIONAL         {'lat': 20.6843008, 'lng': -105.2780858}
# 385     OPERATIONAL           {'lat': 20.684004, 'lng': -105.290116}
# 386     OPERATIONAL  {'lat': 20.68943789999999, 'lng': -105.2845892}
#
#                                                   icon  \
# 0    https://maps.gstatic.com/mapfiles/place_api/ic...
# ...

# %%
df_geo = df1['geometry'].map(eval).apply(pd.Series)

# %%
df_geo.head()
# Out:
#          lat         lng
# 0  20.693901 -105.274238
# 1  20.692073 -105.274730
# 2  20.693907 -105.276324
# 3  20.624147 -105.224322
# 4  20.622593 -105.223252

# %%
df1 = df1.merge(df_geo, how='outer', left_index=True, right_index=True)
df1.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
df1.describe(include='all')
# Out:
#        business_status                                         geometry  \
# count              387                                              387
# unique               1                                              384
# top        OPERATIONAL  {'lat': 20.65340699999999, 'lng': -105.2253316}
# freq               387                                                3
# mean               NaN                                              NaN
# std                NaN                                              NaN
# min                NaN                                              NaN
# 25%                NaN                                              NaN
# 50%                NaN                                              NaN
# 75%                NaN                                              NaN
# max                NaN                                              NaN
#
#                                                      icon        name_x  \
# ...

# %%
df1[df1['geometry']=="{'lat': 20.65340699999999, 'lng': -105.2253316}"]
# Out:
#    business_status                                         geometry  \
# 30     OPERATIONAL  {'lat': 20.65340699999999, 'lng': -105.2253316}
# 31     OPERATIONAL  {'lat': 20.65340699999999, 'lng': -105.2253316}
# 32     OPERATIONAL  {'lat': 20.65340699999999, 'lng': -105.2253316}
#
#                                                  icon           name_x  \
# 30  https://maps.gstatic.com/mapfiles/place_api/ic...  Hard rock hotel
# 31  https://maps.gstatic.com/mapfiles/place_api/ic...  Puerto Vallarta
# 32  https://maps.gstatic.com/mapfiles/place_api/ic...         Sunscape
#
#    opening_hours                                             photos  \
# 30           NaN  [{'height': 3024, 'html_attributions': ['<a hr...
# 31           NaN  [{'height': 1280, 'html_attributions': ['<a hr...
# 32           NaN                                                NaN
#
#                        place_id  \
# 30  ChIJq0pp-CxFIYQRFGcrW0jD2YU
# 31  ChIJJ7hW4RNFIYQReKCg-JvCd5w
# ...

# %%
df1.iloc[3].all_reviews
# Out:
# "['This is interesting, as it appears to be be under new ownership. It has a new paint job on the front, I have not taken time to speak with the new managers. In the past few years I know of people who have did extended vacations as the prices were reasonable. Access in the local community offers many things (I live across the street).  There is a Bus Route to Centro up the hill and return from Centro down the hill. They have a few rooms for Family or Long Term. I have seen Buses unload and many people take over the Hotel in the past. Time will tell.', 'Comfortable and decent, it is 10 minutes from the beach\\nThe water heater does not work and neither does the internet, but good for spending the night', 'Very good cows in Guadalajara', 'Very good', 'Change of administration and they did not make the deposit valid according to why the past administration did not give it to them 😒 I had no other choice than to stay there since according to what I had booked and I had about 50 people o
# ...

# %%
df1.shape
# Out:
# (387, 26)

# %%
df1.to_csv(r'df1csv.csv', index=True, header=True, index_label=False)

# %%
import gensim
