# %%
import requests
import json
import time

import pandas as pd
from googletrans import Translator, constants
from pprint import pprint

# %%
class GooglePlaces(object):
    def __init__(self, apiKey):
        super(GooglePlaces, self).__init__()
        self.apiKey = apiKey
        
    def search_places_by_coordinate(self, location, radius, types):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        places = []
        params = {
            'location': location,
            'radius': radius,
            'types': types,
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        results =  json.loads(res.content)
        places.extend(results['results'])
        time.sleep(2)
        while "next_page_token" in results:
            params['pagetoken'] = results['next_page_token'],
            res = requests.get(endpoint_url, params = params)
            results = json.loads(res.content)
            places.extend(results['results'])
            time.sleep(2)
        return places
    
    def get_place_details(self, place_id, fields):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/details/json"
        params = {
            'placeid': place_id,
            'fields': ",".join(fields),
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        place_details =  json.loads(res.content)
        return place_details

# %%
api = GooglePlaces("AIzaSyAVGW0SZpsJgHMsdW2jYOOfm-iEzY2oKIY")

# %%
hotels = pd.read_csv('hotels_cleaned.csv')

# %%
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
hotels.shape
# Out:
# (346, 26)

# %%
hotels[hotels['rating_x']>3.5]
# Out:
#     business_status                                  geometry  \
# 0       OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1       OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2       OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3       OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4       OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
# ..              ...                                       ...
# 341     OPERATIONAL  {'lat': 20.6778627, 'lng': -105.2852463}
# 342     OPERATIONAL   {'lat': 20.6851287, 'lng': -105.287574}
# 343     OPERATIONAL  {'lat': 20.6828908, 'lng': -105.2788986}
# 344     OPERATIONAL   {'lat': 20.6769383, 'lng': -105.285772}
# 345     OPERATIONAL  {'lat': 20.6843008, 'lng': -105.2780858}
#
#                                                   icon  \
# 0    https://maps.gstatic.com/mapfiles/place_api/ic...
# 1    https://maps.gstatic.com/mapfiles/place_api/ic...
# ...

# %%
hotels['lng'] = hotels['lng'].astype(str)
hotels['lat'] = hotels['lat'].astype(str)

# %%
hotels['long_lat'] = hotels['lng'].str.cat(hotels['lat'],sep=" ")
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
hotels['lat_long'] = hotels['lat'].str.cat(hotels['lng'],sep=" ")
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
hotels.describe(include='all')
# Out:
#        business_status                                         geometry  \
# count              346                                              346
# unique               1                                              345
# top        OPERATIONAL  {'lat': 20.65340699999999, 'lng': -105.2253316}
# freq               346                                                2
# mean               NaN                                              NaN
# std                NaN                                              NaN
# min                NaN                                              NaN
# 25%                NaN                                              NaN
# 50%                NaN                                              NaN
# 75%                NaN                                              NaN
# max                NaN                                              NaN
#
#                                                      icon              name_x  \
# ...

# %%
sorted_hotels = hotels.sort_values(by=['rating_x'],ascending=False)
sorted_hotels.iloc[0:4].name_x.values
# Out:
# array(['NIZA FIVE Luxury Beach Apartments', 'Venetian Vallarta',
#        'Spacio Natural', 'Casa Tabachín'], dtype=object)

# %%
import numpy as np

# %%
sorted_hotels['top_4'] = np.array_str(sorted_hotels.iloc[0:4].name_x.values)

# %%
sorted_hotels.iloc[0].top_4
# Out:
# "['NIZA FIVE Luxury Beach Apartments' 'Venetian Vallarta' 'Spacio Natural'\n 'Casa Tabachín']"

# %%
df_dne = hotels[hotels['business_status']=="dne"]
df_dne.shape[0] == 0
# Out:
# True

# %%
hotels.iloc[0].lat_long
# Out:
# '20.6939009 -105.2742384'

# %%
df_short = hotels.iloc[0:2]
df_short
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                  name_x        opening_hours  \
# 0                        casa LAS PIÑAS  {'open_now': False}
# 1  Villas Victoria Confort Jarretaderas   {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 640, 'html_attributions': ['<a hre...
# 1                                                NaN
#
#                       place_id  \
# 0  ChIJIeVYvYNGIYQRh-9bPVK3fCU
# 1  ChIJdSKPg3xHIYQRlZ0pmfgVPiQ
#
#                                            plus_code  rating_x  \
# 0  {'compound_code': 'MPVG+H8 Jarretaderas, Nayar...       4.6
# ...

# %%
other_places(df_short, df_short['lat_lng'])

# %%
def other_places(coords_string):
    
    
    restaurants = api.search_places_by_coordinate(coords_string, "800", "restaurant")
    
    #make into df first
    restaurants_df = pd.DataFrame(restaurants)
    
    num_restaurants = restaurants_df.shape[0]
    
    try:
        mean_rating_restaurants = restaurants_df['rating'].mean()
    except:
        mean_rating_restaurants = "N/A"
    
    try:
        sorted_restaurants = restaurants_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_restaurants = "N/A"
    
    
    if restaurants_df.shape[0] >=3:
        top_3_restaurants = np.array_str(sorted_restaurants.iloc[0:3].name.values)
    elif restaurants_df.shape[0] == 2:
        top_3_restaurants = np.array_str(sorted_restaurants.iloc[0:2].name.values)
    elif restaurants_df.shape[0] == 1:
        top_3_restaurants = np.array_str(sorted_restaurants.iloc[0:1].name.values)
    else:
        top_3_restaurants = "No Nearby Restaurants"
        
#     print(num_restaurants, mean_rating_restaurants, top_3_restaurants)
        
#     df['num_restaurants'] = num_restaurants
#     df['mean_rating_rest'] = mean_rating_restaurants
#     df['top_3_restaurants'] = top_3_restaurants
    
    return (num_restaurants, mean_rating_restaurants, top_3_restaurants)

# %%
hotels['restaurants'] = hotels.lat_long.apply(other_places)

# %%
hotels.loc[:,'num_restaurants'] = hotels.restaurants.map(lambda x: x[0])
hotels.loc[:,'rest_mean_rating'] = hotels.restaurants.map(lambda x: x[1])
hotels.loc[:,'top_3_restaurants'] = hotels.restaurants.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
def bars(coords_string):
    
    
    bar = api.search_places_by_coordinate(coords_string, "800", "bar")
    
    #make into df first
    bar_df = pd.DataFrame(bar)
    
    num_bar = bar_df.shape[0]
    
    try:
        mean_rating_bar = bar_df['rating'].mean()
    except:
        mean_rating_bar = "N/A"
    
    try:
        sorted_bar = bar_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_bar = "N/A"
    
    if bar_df.shape[0] >=3:
        top_3_bars = np.array_str(sorted_bar.iloc[0:3].name.values)
    elif bar_df.shape[0] == 2:
        top_3_bars = np.array_str(sorted_bar.iloc[0:2].name.values)
    elif bar_df.shape[0] == 1:
        try:
            top_3_bars = np.array_str(sorted_bar.iloc[0:1].name.values)
        except:
            top_3_bars = "No Nearby Bars"
    else:
        top_3_bars = "No Nearby Bars"
    
    return (num_bar, mean_rating_bar, top_3_bars)

# %%
hotels['bars'] = hotels.lat_long.apply(bars)

# %%
hotels.loc[:,'num_bars'] = hotels.bars.map(lambda x: x[0])
hotels.loc[:,'bars_mean_rating'] = hotels.bars.map(lambda x: x[1])
hotels.loc[:,'top_3_bars'] = hotels.bars.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
hotels[hotels['num_bars']==1]
# Out:
#     business_status                                  geometry  \
# 340     OPERATIONAL  {'lat': 20.6816603, 'lng': -105.2795111}
# 343     OPERATIONAL  {'lat': 20.6828908, 'lng': -105.2788986}
#
#                                                   icon  \
# 340  https://maps.gstatic.com/mapfiles/place_api/ic...
# 343  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                          name_x       opening_hours  \
# 340  Grand Luxxe Residence Club  {'open_now': True}
# 343         Grand Luxxe Tower 5                 NaN
#
#                                                 photos  \
# 340  [{'height': 5360, 'html_attributions': ['<a hr...
# 343  [{'height': 2160, 'html_attributions': ['<a hr...
#
#                         place_id  \
# 340  ChIJV63E5SVEIYQRVfhJC548eOg
# 343  ChIJI9D-5CVEIYQRyClZqRFcuoM
#
#                                              plus_code  rating_x  \
# 340  {'compound_code': 'MPJC+M5 Nuevo Vallarta, Nay...       4.7
# ...

# %%
def art_gallery(coords_string):
    
    
    art_gallery = api.search_places_by_coordinate(coords_string, "800", "art_gallery")
    
    #make into df first
    art_df = pd.DataFrame(art_gallery)
    
    num_art_galleries = art_df.shape[0]
    
    try:
        mean_rating_art = art_df['rating'].mean()
    except:
        mean_rating_art = "N/A"
        
    try:
        sorted_art = art_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_art = "N/A"
    
    if art_df.shape[0] >=3:
        top_3_art = np.array_str(sorted_art.iloc[0:3].name.values)
    elif art_df.shape[0] == 2:
        top_3_art = np.array_str(sorted_art.iloc[0:2].name.values)
    elif art_df.shape[0] == 1:
        try:
            top_3_art = np.array_str(sorted_art.iloc[0:1].name.values)
        except:
            top_3_art = "No Nearby Art Galleries"
    else:
        top_3_art = "No Nearby Art Galleries"
    
    return (num_art_galleries, mean_rating_art, top_3_art)

# %%
hotels['art_galleries'] = hotels.lat_long.apply(art_gallery)

# %%
hotels.loc[:,'num_art_galleries'] = hotels.art_galleries.map(lambda x: x[0])
hotels.loc[:,'art_gallery_mean_rating'] = hotels.art_galleries.map(lambda x: x[1])
hotels.loc[:,'top_3_art_galleries'] = hotels.art_galleries.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
def gyms(coords_string):
    
    
    gyms = api.search_places_by_coordinate(coords_string, "800", "gym")
    
    #make into df first
    gyms_df = pd.DataFrame(gyms)
    
    num_gyms = gyms_df.shape[0]
    
    try:
        mean_rating_gyms = gyms_df['rating'].mean()
    except:
        mean_rating_gyms = "N/A"
        
    try:
        sorted_gyms = gyms_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_gyms = "N/A"
    
    if gyms_df.shape[0] >=3:
        top_3_gyms = np.array_str(sorted_gyms.iloc[0:3].name.values)
    elif gyms_df.shape[0] == 2:
        try:
            top_3_gyms = np.array_str(sorted_gyms.iloc[0:2].name.values)
        except:
            top_3_gyms = np.array_str(gyms_df.iloc[0:2].name.values)
    elif gyms_df.shape[0] == 1:
        try:
            top_3_gyms = np.array_str(sorted_gyms.iloc[0:1].name.values)
        except:
            top_3_gyms = "No Nearby Gyms"
    else:
        top_3_gyms = "No Nearby Gyms"
    
    return (num_gyms, mean_rating_gyms, top_3_gyms)

# %%
hotels['gyms'] = hotels.lat_long.apply(gyms)

# %%
hotels.loc[:,'num_gyms'] = hotels.gyms.map(lambda x: x[0])
hotels.loc[:,'gyms_mean_rating'] = hotels.gyms.map(lambda x: x[1])
hotels.loc[:,'top_3_gyms'] = hotels.gyms.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
def shopping_malls(coords_string):
    
    
    shopping = api.search_places_by_coordinate(coords_string, "800", "shopping_mall")
    
    #make into df first
    shopping_df = pd.DataFrame(shopping)
    
    num_shopping = shopping_df.shape[0]
    
    try:
        mean_rating_shopping = shopping_df['rating'].mean()
    except:
        mean_rating_shopping = "N/A"
        
    try:
        sorted_shopping = shopping_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_shopping = "N/A"
    
    if shopping_df.shape[0] >=3:
        try:
            top_3_shopping = np.array_str(sorted_shopping.iloc[0:3].name.values)
        except:
            top_3_shopping = np.array_str(shopping_df.iloc[0:3].name.values)
    elif shopping_df.shape[0] == 2:
        try:
            top_3_shopping = np.array_str(sorted_shopping.iloc[0:2].name.values)
        except:
            top_3_shopping = np.array_str(shopping_df.iloc[0:2].name.values)
    elif shopping_df.shape[0] == 1:
        try:
            top_3_shopping = np.array_str(sorted_shopping.iloc[0:1].name.values)
        except:
            top_3_shopping = np.array_str(shopping_df.iloc[0:1].name.values)
    else:
        top_3_shopping = "No Nearby Shopping Malls"
    
    return (num_shopping, mean_rating_shopping, top_3_shopping)

# %%
hotels['shopping'] = hotels.lat_long.apply(shopping_malls)

# %%
hotels.loc[:,'num_shopping'] = hotels.shopping.map(lambda x: x[0])
hotels.loc[:,'shopping_mean_rating'] = hotels.shopping.map(lambda x: x[1])
hotels.loc[:,'top_3_shopping'] = hotels.shopping.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
def tourist_attractions(coords_string):
    
    
    tours = api.search_places_by_coordinate(coords_string, "800", "tourist_attraction")
    
    #make into df first
    tours_df = pd.DataFrame(tours)
    
    num_tours = tours_df.shape[0]
    
    try:
        mean_rating_tours = tours_df['rating'].mean()
    except:
        mean_rating_tours = "N/A"
    try:
        sorted_tours = tours_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_tours = "N/A"
        
    if tours_df.shape[0] >=3:
        try:
            top_3_tours = np.array_str(sorted_tours.iloc[0:3].name.values)
        except:
            top_3_tours = np.array_str(tours_df.iloc[0:3].name.values)
    elif tours_df.shape[0] == 2:
        try:
            top_3_tours = np.array_str(sorted_tours.iloc[0:2].name.values)
        except:
            top_3_tours = np.array_str(tours_df.iloc[0.2].name.values)
    elif tours_df.shape[0] == 1:
        try:
            top_3_tours = np.array_str(sorted_tours.iloc[0:1].name.values)
        except:
            top_3_tours = np.array_str(tours_df.iloc[0:1].name.values)
    else:
        top_3_tours = "No Nearby Tourist Attractions"
    
    return (num_tours, mean_rating_tours, top_3_tours)

# %%
hotels['tourist'] = hotels.lat_long.apply(tourist_attractions)

# %%
hotels.loc[:,'num_tourist_attract'] = hotels.tourist.map(lambda x: x[0])
hotels.loc[:,'tourist_mean_rating'] = hotels.tourist.map(lambda x: x[1])
hotels.loc[:,'top_3_tourist_attract'] = hotels.tourist.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
hotels.tail()
# Out:
#     business_status                                  geometry  \
# 341     OPERATIONAL  {'lat': 20.6778627, 'lng': -105.2852463}
# 342     OPERATIONAL   {'lat': 20.6851287, 'lng': -105.287574}
# 343     OPERATIONAL  {'lat': 20.6828908, 'lng': -105.2788986}
# 344     OPERATIONAL   {'lat': 20.6769383, 'lng': -105.285772}
# 345     OPERATIONAL  {'lat': 20.6843008, 'lng': -105.2780858}
#
#                                                   icon  \
# 341  https://maps.gstatic.com/mapfiles/place_api/ic...
# 342  https://maps.gstatic.com/mapfiles/place_api/ic...
# 343  https://maps.gstatic.com/mapfiles/place_api/ic...
# 344  https://maps.gstatic.com/mapfiles/place_api/ic...
# 345  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                 name_x       opening_hours  \
# 341      Grand Luxxe Tower 1 at Vidanta Nuevo Vallarta  {'open_now': True}
# 342                         Grupo Vidanta Headquarters                 NaN
# ...

# %%
def casinos(coords_string):
    
    
    casinos = api.search_places_by_coordinate(coords_string, "800", "casino")
    
    #make into df first
    casinos_df = pd.DataFrame(casinos)
    
    num_casinos = casinos_df.shape[0]
    
    try:
        mean_rating_casinos = supermarkets_df['rating'].mean()
    except:
        mean_rating_casinos = "N/A"
    try:
        sorted_casinos = casinos_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_casinos = "N/A"
        
    if casinos_df.shape[0] >=3:
        top_3_casinos = np.array_str(sorted_casinos.iloc[0:3].name.values)
    elif casinos_df.shape[0] == 2:
        try:
            top_3_casinos = np.array_str(sorted_casinos.iloc[0:2].name.values)
        except:
            top_3_casinos = np.array_str(casinos_df.iloc[0:2].name.values)
    elif casinos_df.shape[0] == 1:
        try:
            top_3_casinos = np.array_str(sorted_casinos.iloc[0:1].name.values)
        except:
            top_3_casinos = np.array_str(casinos_df.iloc[0:1].name.values)
    else:
        top_3_casinos = "No Nearby Casinos"
    
    return (num_casinos, mean_rating_casinos, top_3_casinos)

# %%
hotels['casinos'] = hotels.lat_long.apply(casinos)

# %%
hotels.loc[:,'num_casinos'] = hotels.casinos.map(lambda x: x[0])
hotels.loc[:,'casinos_mean_rating'] = hotels.casinos.map(lambda x: x[1])
hotels.loc[:,'top_casinos'] = hotels.casinos.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
def supermarkets(coords_string):
    
    
    supermarkets = api.search_places_by_coordinate(coords_string, "800", "supermarket")
    
    #make into df first
    supermarkets_df = pd.DataFrame(supermarkets)
    
    num_supermarkets = supermarkets_df.shape[0]
    
    try:
        mean_rating_supermarkets = supermarkets_df['rating'].mean()
    except:
        mean_rating_supermarkets = "N/A"
    try:
        sorted_supermarkets = supermarkets_df.sort_values(by=['rating'],ascending=False)
    except:
        sorted_supermarkets = "N/A"
        
    if supermarkets_df.shape[0] >=3:
        try:
            top_3_supermarkets = np.array_str(sorted_supermarkets.iloc[0:3].name.values)
        except:
            top_3_supermarkets = np.array_str(supermarkets_df.iloc[0:3].name.values)
    elif supermarkets_df.shape[0] == 2:
        try:
            top_3_supermarkets = np.array_str(sorted_supermarkets.iloc[0:2].name.values)
        except:
            top_3_supermarkets = np.array_str(supermarkets_df.iloc[0:2].name.values)
    elif supermarkets_df.shape[0] == 1:
        try:
            top_3_supermarkets = np.array_str(sorted_supermarkets.iloc[0:1].name.values)
        except:
            top_3_supermarkets = np.array_str(supermarkets_df.iloc[0:2].name.values)
    else:
        top_3_supermarkets = "No Nearby Supermarkets"
    
    return (num_supermarkets, mean_rating_supermarkets, top_3_supermarkets)

# %%
hotels['supermarkets'] = hotels.lat_long.apply(supermarkets)

# %%
hotels.loc[:,'num_supermarkets'] = hotels.supermarkets.map(lambda x: x[0])
hotels.loc[:,'supermarkets_mean_rating'] = hotels.supermarkets.map(lambda x: x[1])
hotels.loc[:,'top_3_supermarkets'] = hotels.supermarkets.map(lambda x: x[2])
hotels.head()
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
# 2     OPERATIONAL  {'lat': 20.6939068, 'lng': -105.2763239}
# 3     OPERATIONAL  {'lat': 20.6241471, 'lng': -105.2243218}
# 4     OPERATIONAL  {'lat': 20.6225929, 'lng': -105.2232518}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                               name_x        opening_hours  \
# 0                                     casa LAS PIÑAS  {'open_now': False}
# 1               Villas Victoria Confort Jarretaderas   {'open_now': True}
# ...

# %%
hotels.columns
# Out:
# Index(['business_status', 'geometry', 'icon', 'name_x', 'opening_hours',
#        'photos', 'place_id', 'plus_code', 'rating_x', 'reference', 'scope',
#        'types', 'user_ratings_total_x', 'vicinity', 'price_level_x',
#        'international_phone_number', 'name_y', 'rating_y', 'reviews',
#        'user_ratings_total_y', 'website', 'all_ratings', 'all_reviews',
#        'price_level_y', 'lat', 'lng', 'long_lat', 'lat_long', 'restaurants',
#        'num_restaurants', 'rest_mean_rating', 'top_3_restaurants', 'bars',
#        'num_bars', 'bars_mean_rating', 'top_3_bars', 'art_galleries',
#        'num_art_galleries', 'art_gallery_mean_rating', 'top_3_art_galleries',
#        'gyms', 'num_gyms', 'gyms_mean_rating', 'top_3_gyms', 'shopping',
#        'num_shopping', 'shopping_mean_rating', 'top_3_shopping', 'tourist',
#        'num_tourist_attract', 'tourist_mean_rating', 'top_3_tourist_attract',
#        'casinos', 'num_casinos', 'casinos_mean_rating', 'top_casinos',
# ...

# %%
hotels.shape
# Out:
# (346, 60)

# %%
hotels.to_csv(r'hotels_others_complete.csv', index=True, header=True, index_label=False)

# %%
# df_short.iloc[0].restaurants
# Out:
# (48,
#  4.594117647058823,
#  '["Marley\'s Café" \'Carnitas el gordo\' \'Loncheria la México\']')

# %%
# df_short.loc[:,'num_restaurants'] = df_short.restaurants.map(lambda x: x[0])
# df_short.loc[:,'rest_mean_rating'] = df_short.restaurants.map(lambda x: x[1])
# df_short.loc[:,'top_3_restaurants'] = df_short.restaurants.map(lambda x: x[2])
# df_short
# Out:
#   business_status                                  geometry  \
# 0     OPERATIONAL  {'lat': 20.6939009, 'lng': -105.2742384}
# 1     OPERATIONAL  {'lat': 20.6920731, 'lng': -105.2747303}
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                  name_x        opening_hours  \
# 0                        casa LAS PIÑAS  {'open_now': False}
# 1  Villas Victoria Confort Jarretaderas   {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 640, 'html_attributions': ['<a hre...
# 1                                                NaN
#
#                       place_id  \
# 0  ChIJIeVYvYNGIYQRh-9bPVK3fCU
# 1  ChIJdSKPg3xHIYQRlZ0pmfgVPiQ
#
#                                            plus_code  rating_x  \
# 0  {'compound_code': 'MPVG+H8 Jarretaderas, Nayar...       4.6
# ...

# %%
# x = df_short.lat_long.apply(other_places)
# Out:
# 48 4.594117647058823 ["Marley's Café" 'Carnitas el gordo' 'Loncheria la México']
# 38 4.523076923076923 ['BLUE TARP RESTAURANT - MAGO' 'La Xitana Crepas' 'Loncheria la México']

# %%
# type(x)
# Out:
# pandas.core.series.Series

# %%
# pd.DataFrame(x)
# Out:
#                                             lat_long
# 0  (48, 4.594117647058823, ["Marley's Café" 'Carn...
# 1  (38, 4.523076923076923, ['BLUE TARP RESTAURANT...

# %%
# df_short['num_restaurants'], df_short['mean_rating_restaurants'], df_short['top_3_restaurants'] = df_short.lat_long.apply(other_places)
# Out:
# 48 4.594117647058823 ["Marley's Café" 'Carnitas el gordo' 'Loncheria la México']
# 38 4.523076923076923 ['BLUE TARP RESTAURANT - MAGO' 'La Xitana Crepas' 'Loncheria la México']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-f0f577488b57> in <module>
# ----> 1 df_short['num_restaurants'], df_short['mean_rating_restaurants'], df_short['top_3_restaurants'] = df_short.lat_long.apply(other_places)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# df_short.head()

# %%
# restaurants = api.search_places_by_coordinate("20.6939009 -105.2742384", "800", "restaurant")

# %%
#make into df first
# restaurants_df = pd.DataFrame(restaurants)
    
# num_restaurants = restaurants_df.shape[0]
    
# mean_rating_restaurants = restaurants_df['rating'].mean()
    
# sorted_restaurants = restaurants_df.sort_values(by=['rating'],ascending=False)
    
# if restaurants_df.shape[0] >=3:
#     top_3_restaurants = np.array_str(sorted_restaurants.iloc[0:3].name.values)
# elif restaurants_df.shape[0] == 2:
#     top_3_restaurants = np.array_str(sorted_restaurants.iloc[0:2].name.values)
# elif restaurants_df.shape[0] == 1:
#     top_3_restaurants = np.array_str(sorted_restaurants.iloc[0:1].name.values)
# else:
#     top_3_restaurants = "No Nearby Restaurants"
        
        
    
# df['num_restaurants'] = num_restaurants
# df['mean_rating_rest'] = mean_rating_restaurants
# df['top_3_restaurants'] = top_3_restaurants

# %%
# mean_rating_restaurants
# Out:
# 4.594117647058823

# %%
# restaurants_df.head()
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 20.6938154, 'lng': -105.2...
# 1     OPERATIONAL  {'location': {'lat': 20.6911818, 'lng': -105.2...
# 2     OPERATIONAL  {'location': {'lat': 20.6939253, 'lng': -105.2...
# 3     OPERATIONAL  {'location': {'lat': 20.6941587, 'lng': -105.2...
# 4     OPERATIONAL  {'location': {'lat': 20.6931104, 'lng': -105.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                              name        opening_hours  \
# 0  The Blue Shrimp Nuevo Vallarta  {'open_now': False}
# 1                 Claudio's Place  {'open_now': False}
# 2             Loncheria la México   {'open_now': True}
# ...
